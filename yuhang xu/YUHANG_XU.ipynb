# %%
import pandas as pd
import time 
rng = pd.date_range('2022/01/04','2022/04/29' ,freq='D').strftime('%Y-%m-%d').tolist()
rng.remove('2022-02-28')
rng.remove('2022-04-15')
rng.remove('2022-04-18')
data_list = []
for date in rng:
    if time.strptime(date,'%Y-%m-%d').tm_wday<5:
        print(date)
        ##print('https://dsc-mp2022.s3.amazonaws.com/proj-b/dataset-b01/Tst{}tapes.csv'.format(date))
        tmp = pd.read_csv('https://dsc-mp2022.s3.amazonaws.com/proj-b/dataset-b01/Tst{}tapes.csv'.format(date),header=  None)
        data_list.append(tmp.tail(1))
# Out:
# 2022-01-04
# 2022-01-05
# 2022-01-06
# 2022-01-07
# 2022-01-10
# 2022-01-11
# 2022-01-12
# 2022-01-13
# 2022-01-14
# 2022-01-17
# 2022-01-18
# 2022-01-19
# 2022-01-20
# 2022-01-21
# 2022-01-24
# 2022-01-25
# 2022-01-26
# 2022-01-27
# 2022-01-28
# 2022-01-31
# 2022-02-01
# 2022-02-02
# 2022-02-03
# 2022-02-04
# 2022-02-07
# 2022-02-08
# 2022-02-09
# 2022-02-10
# 2022-02-11
# 2022-02-14
# 2022-02-15
# 2022-02-16
# 2022-02-17
# 2022-02-18
# 2022-02-21
# 2022-02-22
# 2022-02-23
# 2022-02-24
# 2022-02-25
# 2022-03-01
# 2022-03-02
# 2022-03-03
# 2022-03-04
# 2022-03-07
# 2022-03-08
# 2022-03-09
# 2022-03-10
# 2022-03-11
# 2022-03-14
# 2022-03-15
# 2022-03-16
# 2022-03-17
# 2022-03-18
# 2022-03-21
# 2022-03-22
# 2022-03-23
# 2022-03-24
# 2022-03-25
# 2022-03-28
# 2022-03-29
# 2022-03-30
# 2022-03-31
# 2022-04-01
# 2022-04-04
# 2022-04-05
# 2022-04-06
# 2022-04-07
# 2022-04-08
# 2022-04-11
# 2022-04-12
# 2022-04-13
# 2022-04-14
# 2022-04-19
# 2022-04-20
# 2022-04-21
# 2022-04-22
# 2022-04-25
# 2022-04-26
# 2022-04-27
# 2022-04-28
# 2022-04-29

# %%
afterday_set = pd.concat(data_list,ignore_index = True)

# %%
afterday_set.head()
# Out:
#               0          1          2    3                        4   \
# 0  Tst2022-01-04   Exch0Lit  30598.864  219   {'pool_id': 'Exch0Lit'
# 1  Tst2022-01-05   Exch0Lit  30599.712  212   {'pool_id': 'Exch0Lit'
# 2  Tst2022-01-06   Exch0Lit  30597.664  190   {'pool_id': 'Exch0Lit'
# 3  Tst2022-01-07   Exch0Lit  30598.880  206   {'pool_id': 'Exch0Lit'
# 4  Tst2022-01-10   Exch0Lit  30599.584  211   {'pool_id': 'Exch0Lit'
#
#                  5                   6              7          8   \
# 0   'type': 'Trade'   'time': 30598.864   'price': 219   'qty': 1
# 1   'type': 'Trade'   'time': 30599.712   'price': 212   'qty': 2
# 2   'type': 'Trade'   'time': 30597.664   'price': 190   'qty': 3
# 3   'type': 'Trade'    'time': 30598.88   'price': 206   'qty': 1
# 4   'type': 'Trade'   'time': 30599.584   'price': 211   'qty': 2
#
#                  9                  10
# 0   'party1': 'S19'   'party2': 'B24'}
# 1   'party1': 'S14'   'party2': 'B03'}
# 2   'party1': 'S13'   'party2': 'B15'}
# 3   'party1': 'S02'   'party2': 'B28'}
# 4   'party1': 'S19'   'party2': 'B15'}

# %%
afterday_set[0]= afterday_set[0].apply(lambda x: x[3:])

# %%
afterday_set.head()
# Out:
#            0          1          2    3                        4   \
# 0  2022-01-04   Exch0Lit  30598.864  219   {'pool_id': 'Exch0Lit'
# 1  2022-01-05   Exch0Lit  30599.712  212   {'pool_id': 'Exch0Lit'
# 2  2022-01-06   Exch0Lit  30597.664  190   {'pool_id': 'Exch0Lit'
# 3  2022-01-07   Exch0Lit  30598.880  206   {'pool_id': 'Exch0Lit'
# 4  2022-01-10   Exch0Lit  30599.584  211   {'pool_id': 'Exch0Lit'
#
#                  5                   6              7          8   \
# 0   'type': 'Trade'   'time': 30598.864   'price': 219   'qty': 1
# 1   'type': 'Trade'   'time': 30599.712   'price': 212   'qty': 2
# 2   'type': 'Trade'   'time': 30597.664   'price': 190   'qty': 3
# 3   'type': 'Trade'    'time': 30598.88   'price': 206   'qty': 1
# 4   'type': 'Trade'   'time': 30599.584   'price': 211   'qty': 2
#
#                  9                  10
# 0   'party1': 'S19'   'party2': 'B24'}
# 1   'party1': 'S14'   'party2': 'B03'}
# 2   'party1': 'S13'   'party2': 'B15'}
# 3   'party1': 'S02'   'party2': 'B28'}
# 4   'party1': 'S19'   'party2': 'B15'}

# %%
type(afterday_set)
# Out:
# pandas.core.frame.DataFrame

# %%
afterday_set[0]= afterday_set[0].apply(lambda x: x[3:])

# %%
afterday_set.head()
# Out:
#         0          1          2    3                        4   \
# 0  2-01-04   Exch0Lit  30598.864  219   {'pool_id': 'Exch0Lit'
# 1  2-01-05   Exch0Lit  30599.712  212   {'pool_id': 'Exch0Lit'
# 2  2-01-06   Exch0Lit  30597.664  190   {'pool_id': 'Exch0Lit'
# 3  2-01-07   Exch0Lit  30598.880  206   {'pool_id': 'Exch0Lit'
# 4  2-01-10   Exch0Lit  30599.584  211   {'pool_id': 'Exch0Lit'
#
#                  5                   6              7          8   \
# 0   'type': 'Trade'   'time': 30598.864   'price': 219   'qty': 1
# 1   'type': 'Trade'   'time': 30599.712   'price': 212   'qty': 2
# 2   'type': 'Trade'   'time': 30597.664   'price': 190   'qty': 3
# 3   'type': 'Trade'    'time': 30598.88   'price': 206   'qty': 1
# 4   'type': 'Trade'   'time': 30599.584   'price': 211   'qty': 2
#
#                  9                  10
# 0   'party1': 'S19'   'party2': 'B24'}
# 1   'party1': 'S14'   'party2': 'B03'}
# 2   'party1': 'S13'   'party2': 'B15'}
# 3   'party1': 'S02'   'party2': 'B28'}
# 4   'party1': 'S19'   'party2': 'B15'}

# %%
afterday_set = afterday_set.set_index(keys=[0])

# %%
afterday_set.rename(columns={'0':'date'})
# Out:
#                 1          2    3                        4                 5   \
# 0
# 2-01-04   Exch0Lit  30598.864  219   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-01-05   Exch0Lit  30599.712  212   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-01-06   Exch0Lit  30597.664  190   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-01-07   Exch0Lit  30598.880  206   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-01-10   Exch0Lit  30599.584  211   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# ...            ...        ...  ...                      ...               ...
# 2-04-25   Exch0Lit  30599.520  140   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-04-26   Exch0Lit  30599.840  146   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-04-27   Exch0Lit  30599.552  140   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-04-28   Exch0Lit  30599.024  133   {'pool_id': 'Exch0Lit'   'type': 'Trade'
# 2-04-29   Exch0Lit  30599.776  133   {'pool_id': 'Exch0Lit'   'type': 'Trade'
#
#                          6              7          8                 9   \
# 0
# 2-01-04   'time': 30598.864   'price': 219   'qty': 1   'party1': 'S19'
# 2-01-05   'time': 30599.712   'price': 212   'qty': 2   'party1': 'S14'
# 2-01-06   'time': 30597.664   'price': 190   'qty': 3   'party1': 'S13'
# 2-01-07    'time': 30598.88   'price': 206   'qty': 1   'party1': 'S02'
# 2-01-10   'time': 30599.584   'price': 211   'qty': 2   'party1': 'S19'
# ...                     ...            ...        ...               ...
# 2-04-25    'time': 30599.52   'price': 140   'qty': 2   'party1': 'S00'
# 2-04-26    'time': 30599.84   'price': 146   'qty': 1   'party1': 'S12'
# 2-04-27   'time': 30599.552   'price': 140   'qty': 4   'party1': 'S13'
# 2-04-28   'time': 30599.024   'price': 133   'qty': 2   'party1': 'S16'
# 2-04-29   'time': 30599.776   'price': 133   'qty': 1   'party1': 'S04'
#
#                         10
# 0
# 2-01-04   'party2': 'B24'}
# 2-01-05   'party2': 'B03'}
# 2-01-06   'party2': 'B15'}
# 2-01-07   'party2': 'B28'}
# 2-01-10   'party2': 'B15'}
# ...                    ...
# 2-04-25   'party2': 'B04'}
# 2-04-26   'party2': 'B05'}
# 2-04-27   'party2': 'B27'}
# 2-04-28   'party2': 'B25'}
# 2-04-29   'party2': 'B19'}
#
# [81 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import math 
from statsmodels.tsa.arima_model import ARIMA 
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
close_price = afterday_set[7]

# %%
afterday_set['price'] = afterday_set[7].apply(lambda x: int(x[-3:]))

# %%
plt.plot(afterday_set.index,afterday_set['price'])
plt.show()

# %%
to_row = int(len(afterday_set)*0.9)

# %%
training_data = list(afterday_set[0:to_row]['price'])
testing_data = list(afterday_set[to_row:]['price'])

# %%
import matplotlib.pyplot as plt
import math 
from statsmodels.tsa.arima_model import ARIMA 
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
model_predictions = []

# %%
for i in range(9):
    model = ARIMA(training_data,order = (4,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = list(output[0])[0]
    model_predictions.append(yhat)
    actual_test_value = testing_data[i]
    training_data.append(actual_test_value)
    print(output)
# Out:
# (array([161.99995061]), array([21.9352782]), array([[119.00759535, 204.99230586]]))
# (array([170.36646253]), array([21.78528949]), array([[127.66807974, 213.06484532]]))
# (array([157.76549478]), array([21.70954578]), array([[115.21556692, 200.31542263]]))
# (array([127.44380599]), array([22.16702996]), array([[ 83.99722563, 170.89038635]]))
# (array([156.9687783]), array([22.09164418]), array([[113.66995135, 200.26760524]]))
# (array([131.65912746]), array([22.03077511]), array([[ 88.4796017 , 174.83865321]]))
# (array([144.62810218]), array([21.94458355]), array([[101.61750877, 187.63869559]]))
# (array([133.52107445]), array([21.80947496]), array([[ 90.77528901, 176.2668599 ]]))
# (array([135.34998819]), array([21.67095662]), array([[ 92.87569371, 177.82428266]]))

# %%
plt.figure(figsize = (15,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing prices')
plt.plot(afterday_set[0:to_row]['price'],'green',label = 'Train data')
plt.plot(afterday_set[to_row:]['price'],'blue',label = 'Test data')
plt.legend()

# %%
plt.figure(figsize = (15,9))
plt.grid(True)

date_range = afterday_set[to_row:].index
plt.plot(date_range,model_predictions[:],color = 'blue',marker = 'o',linestyle = 'dashed',label = 'Predicted Stock price')
plt.plot(date_range,testing_data,color = 'red',label = 'Actual Stock price')
plt.title('Closing price prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
